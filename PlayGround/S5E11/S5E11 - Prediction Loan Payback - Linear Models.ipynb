# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

gp_transformer = joblib.load("kaggle/working/model/" + "gpt.joblib")

# %%
gp_transformer.feature_names_in_
# Out:
# array(['int__annual_income', 'int__debt_to_income_ratio',
#        'int__credit_score', 'int__loan_amount', 'int__interest_rate',
#        'int__annual_incomeXcredit_score', 'int__loan_to_income',
#        'int__interest_burden', 'int__log_income', 'int__log_loan_amount',
#        'int__debt_to_income_ratio_diff', 'int__debt_to_income_ratio_norm',
#        'int__risk_map', 'int__credit_dti_interaction',
#        'int__income_dti_interaction', 'cat__employment_status',
#        'cat__grade_subgrade'], dtype=object)
